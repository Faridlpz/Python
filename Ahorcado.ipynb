# %%
#Proyecto de ahorcado Series

#Entender el problema y como implementarlo
#Una matriz que contendra 10 palabras alazar
#Ciclo el cual le preguntara que ingrese una palabra si es incorrecta tendra una falla, en caso de fallar 3 veces el juego terminara
#De lo contrario podra seguir intentando

# %%
from random import choice
import re
from collections import Counter

vector = ['Sabrina','Breaking bad','Stranger things','Dark']


palabra_aleatoria = choice(vector)


sus1 = 'aeiounkhg'
sus2 = '_________'
cambio = str.maketrans(sus1,sus2)
str=palabra_aleatoria


if palabra_aleatoria == 'Sabrina':
    print("Debe enfrentar su naturaleza como mitad bruja y mitad mortal mientras lucha contra las fuerzas del mal que la amenazan a ella, a su familia y el mundo en que habitan los humanos")
elif palabra_aleatoria == 'Breaking bad':
    print('Es un frustrado profesor de química en un instituto, padre de un joven discapacitado y con una mujer embarazada. Además, trabaja en un lavadero de vehículos por las tardes.')
elif palabra_aleatoria == 'Stranger things':
    print('La historia arranca durante la década de los 80, en el pueblo ficticio de Hawkins, Indiana, cuando un niño llamado Will Byers desaparece misteriosamente')
elif palabra_aleatoria == 'Dark':
    print('En la ciudad de Winden comienzan a producirse desapariciones de niños, sacando a la luz las relaciones fracturadas, vidas dobles y el pasado oscuro de cuatro familias que viven allí, y revelando un misterio que abarca cuatro generaciones.')

print()

aux=str.translate(cambio)
#print(str.translate(cambio))
va=list(aux)
pa = list(palabra_aleatoria)


ban = 0
ban1= 0
ban3 = 0

while ban3 < 3:
    print(va)
    print()
    print()
    ban1=0
    adivinar = input('Ingrese una letra para adivinar la palabra. ')
    for i,variable in enumerate(palabra_aleatoria):
        if variable == adivinar:
            ban1=1
            va[i] = va[i].join(adivinar)
            
    if ban1==1:
        print(adivinar,' Es una palabra correcta')  
        print()
    else:
        ban3 = ban3+1
        print(adivinar,' Es una palabra incorrecta')
        print()
        
    if ban3 == 3 :
        print('GAME OVER')
        print()
        
    if pa == va:
        print(pa)
        print()
        print()
        print("A GANADO EL GAME")
        break
# Out:
# La historia arranca durante la década de los 80, en el pueblo ficticio de Hawkins, Indiana, cuando un niño llamado Will Byers desaparece misteriosamente
#
# ['S', 't', 'r', '_', '_', '_', '_', 'r', ' ', 't', '_', '_', '_', '_', 's']
#
#
# Ingrese una letra para adivinar la palabra. a
# a  Es una palabra correcta
#
# ['S', 't', 'r', 'a', '_', '_', '_', 'r', ' ', 't', '_', '_', '_', '_', 's']
#
#
# Ingrese una letra para adivinar la palabra. n
# n  Es una palabra correcta
#
# ['S', 't', 'r', 'a', 'n', '_', '_', 'r', ' ', 't', '_', '_', 'n', '_', 's']
#
#
# Ingrese una letra para adivinar la palabra. g
# g  Es una palabra correcta
#
# ['S', 't', 'r', 'a', 'n', 'g', '_', 'r', ' ', 't', '_', '_', 'n', 'g', 's']
#
#
# Ingrese una letra para adivinar la palabra. e
# e  Es una palabra correcta
#
# ['S', 't', 'r', 'a', 'n', 'g', 'e', 'r', ' ', 't', '_', '_', 'n', 'g', 's']
#
#
# Ingrese una letra para adivinar la palabra. h
# h  Es una palabra correcta
#
# ...
